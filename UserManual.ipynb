# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from main import NetworkSimulation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
g = NetworkSimulation(graph_type='category')

# %%
g.simulation_category()

# %%
g.choice_history
# Out:
# array([[ 3,  7,  8,  8,  3,  2,  4,  5,  4,  9,  2,  5,  5,  4,  1,  2,  9,
#          6,  5,  8],
#        [ 1,  4,  8,  2,  5,  7,  3, 10,  7,  7,  1, 10,  5,  8,  7,  3, 10,
#          9,  1,  6],
#        [ 5,  7,  8,  4,  8,  7,  6,  6,  5,  5,  1,  3,  8, 10,  7,  7,  4,
#          5,  9,  7],
#        [ 2, 10,  4,  1,  3,  6,  1,  7,  9,  7,  1,  5,  9,  1,  1,  6,  6,
#         10,  8,  4],
#        [ 3, 10,  4,  3,  2, 10,  7,  5,  2,  6,  4,  1,  8,  8, 10,  7,  8,
#          6,  6,  9],
#        [ 6,  1,  9, 10,  3,  3,  9,  6,  7,  4,  1,  9,  8,  1, 10,  8,  6,
#          8,  4,  2],
#        [ 3, 10,  7,  3,  1,  3,  5,  5,  5,  6,  7,  2,  5,  4,  4,  3,  9,
#          9,  5,  1],
#        [ 5,  3,  6,  5,  1,  4,  6,  4,  9,  4,  4,  4,  5,  9,  7,  9,  4,
#          2,  8,  9],
#        [ 2,  8,  2,  4, 10,  8,  4,  1,  8,  4,  2,  6,  2,  8,  2,  3,  9,
#          2,  2,  2],
#        [ 9,  8,  9,  8,  9,  3,  9,  8,  7,  4,  5,  1,  5,  3,  3,  7,  5,
# ...

# %%
g.output_matrix_for_category()
# Out:
# [[{'average similarity': 0,
#    'choice history': [3],
#    'current category': 3,
#    'perceived quality': 0.47385309201017006,
#    'rank': 16,
#    'round': 0,
#    'status change': 0,
#    'status score': 0.14480976202916282},
#   {'average similarity': 0,
#    'choice history': [1],
#    'current category': 1,
#    'perceived quality': 3.8294862213834651,
#    'rank': 26,
#    'round': 0,
#    'status change': 0,
#    'status score': 0.84693496981776217},
#   {'average similarity': 0,
#    'choice history': [5],
#    'current category': 5,
#    'perceived quality': -4.3820790755725794,
#    'rank': 6,
#    'round': 0,
#    'status change': 0,
#    'status score': -0.87577697372909113},
#   {'average similarity': 0,
#    'choice history': [2],
#    'current category': 2,
#    'perceived quality': 10.881198472408943,
#    'rank': 28,
#    'round': 0,
#    'status change': 0,
#    'status score': 2.337599936275145},
#   {'average similarity': 0,
#    'choice history': [3],
# ...

# %%
len(g.sim_dicts)
# Out:
# 19

# %%
sqr_list = g.status_quality_reordering_list()

# %%
plt.figure(figsize=(20,12))
plt.plot(sqr_list)

# %%
sqg_list = g.status_quality_gap_list()

# %%
plt.figure(figsize=(20,12))
plt.plot(sqg_list)
plt.xticks(range(0,20))
# Out:
# ([<matplotlib.axis.XTick at 0x29136671f60>,
# ...
#  <a list of 20 Text xticklabel objects>)

# %%
avg_conv = g.average_converging_time()

# %%
avg_conv
# Out:
# 1

# %%
g = NetworkSimulation(graph_type='random')

# %%
g.simulation()
# Out:
# 0.73392658509454956

# %%
sqr_list = g.status_quality_reordering_list()

# %%
plt.figure(figsize=(20,12))
plt.plot(sqr_list)

# %%
sqg_list = g.status_quality_gap_list()

# %%
plt.figure(figsize=(20,12))
plt.plot(sqg_list)
plt.xticks(range(0,20))
# Out:
# ([<matplotlib.axis.XTick at 0x2913552c6a0>,
# ...
#  <a list of 20 Text xticklabel objects>)

# %%
avg_conv = g.average_converging_time()

# %%
avg_conv
# Out:
# 5

# %%
from ultimate_simulation import ultimate_iteration

# %%
ultimate_iteration()
# Out:
# ...
#  78%|███████▊  | 78/100 [00:32<00:09,  2.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-77b444691312> in <module>()
# ----> 1 ultimate_iteration()
#
# ~\Desktop\simu\NetworkSimulaiton2\ultimate_simulation.py in ultimate_iteration()
#      15                 params = {'h':each[0], 'w':each[1], 's':each[2]}
#      16                 g = NetworkSimulation(**params)
# ---> 17                 cor, gini, avg_conv, abs_sqg = g.multiple_simulations()
#      18                 cor_list.append(cor)
#      19                 gini_list.append(gini)
#
# ~\Desktop\simu\NetworkSimulaiton2\main.py in multiple_simulations(self)
#     158                 for ii in tqdm.trange(100):
#     159                         if self.graph_type != 'category':
# --> 160                                 cor, gini, avg_conv, abs_sqg = self.simulation()
# ...
